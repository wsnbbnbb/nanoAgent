# %%
from openai import OpenAI

client = OpenAI(
  base_url = "https://integrate.api.nvidia.com/v1",
  api_key = "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"
)


completion = client.chat.completions.create(
  model="deepseek-ai/deepseek-v4-flash",
  messages=[{"role":"user","content":"fuck"}],
  temperature=1,
  top_p=0.95,
  max_tokens=16384,
  extra_body={"chat_template_kwargs":{"thinking":True,"reasoning_effort":"low"}},
  stream=True
)

for chunk in completion:
  if not getattr(chunk, "choices", None):
    continue
  reasoning = getattr(chunk.choices[0].delta, "reasoning", None) or getattr(chunk.choices[0].delta, "reasoning_content", None)
  if reasoning:
    print(reasoning, end="")
  if chunk.choices and chunk.choices[0].delta.content is not None:
    print(chunk.choices[0].delta.content, end="")

# %%
from openai import OpenAI
import os
import sys

_USE_COLOR = sys.stdout.isatty() and os.getenv("NO_COLOR") is None
_REASONING_COLOR = "\033[90m" if _USE_COLOR else ""
_RESET_COLOR = "\033[0m" if _USE_COLOR else ""

client = OpenAI(
  base_url = "https://integrate.api.nvidia.com/v1",
  api_key = "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"
)


completion = client.chat.completions.create(
  model="z-ai/glm-5.1",
  messages=[{"role":"user","content":"fuck"}],
  temperature=1,
  top_p=1,
  max_tokens=16384,
  extra_body={"chat_template_kwargs":{"enable_thinking":True,"clear_thinking":False}},
  stream=True
)

for chunk in completion:
  if not getattr(chunk, "choices", None):
    continue
  if len(chunk.choices) == 0 or getattr(chunk.choices[0], "delta", None) is None:
    continue
  delta = chunk.choices[0].delta
  reasoning = getattr(delta, "reasoning_content", None)
  if reasoning:
    print(f"{_REASONING_COLOR}{reasoning}{_RESET_COLOR}", end="")
  if getattr(delta, "content", None) is not None:
    print(delta.content, end="")

# %%
import requests, base64

invoke_url = "https://integrate.api.nvidia.com/v1/chat/completions"
stream = False


headers = {
  "Authorization": "Bearer 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",
  "Accept": "text/event-stream" if stream else "application/json"
}

payload = {
  "model": "moonshotai/kimi-k2.5",
  "messages": [{"role":"user","content":"fuck,i am so tired how about you"}],
  "max_tokens": 16384,
  "temperature": 1.00,
  "top_p": 1.00,
  "stream": stream,
  "chat_template_kwargs": {"thinking":True},
}



response = requests.post(invoke_url, headers=headers, json=payload)

if stream:
    for line in response.iter_lines():
        if line:
            print(line.decode("utf-8"))
else:
    print(response.json())
# Out:
# {'id': 'chatcmpl-b46ec07a14a87fd4', 'object': 'chat.completion', 'created': 1777205265, 'model': 'moonshotai/kimi-k2.5', 'choices': [{'index': 0, 'message': {'role': 'assistant', 'content': " I feel that energy. I don't physically get tired, but I've definitely been grinding through a lot of conversations today too.\n\nWhat's got you wiped? Work? Life? Or just one of those weeks where everything piles up at once?", 'refusal': None, 'annotations': None, 'audio': None, 'function_call': None, 'tool_calls': [], 'reasoning': ' The user is expressing exhaustion/frustration ("fuck, i am so tired") and asking how I am ("how about you"). \n\n First, I need to acknowledge their feelings in a supportive, casual way since they\'re using informal language. They seem to want a conversational, empathetic response.\n\n I should:\n 1. Validate their tiredness/exhaustion\n 2. Answer their question about how I am (as an AI, I don\'t get tired, but I can relate to the feeling of processing a lot or meta
# ...

# %%
def read(path, offset=None, limit=None):
    """
    读取文件，支持分页和行号显示。
    
    特点:
    - 支持 offset/limit 参数，适合读取大文件的特定部分
    - 自动添加行号，便于定位和编辑
    - 使用 readlines() 保持行尾换行符
    
    参数:
        path: 文件路径
        offset: 起始行号（0-based）
        limit: 读取行数
    
    返回:
        str: 带行号的文件内容，或错误信息
    """
    try:
        with open(path, 'r') as f:
            lines = f.readlines()
        
        # 计算起始和结束行
        start = offset if offset else 0
        end = start + limit if limit else len(lines)
        
        # 添加行号（4位宽度，右对齐）
        numbered = [f"{i+1:4d} {line}" for i, line in enumerate(lines[start:end], start)]
        return ''.join(numbered)
    except Exception as e:
        return f"Error: {str(e)}"
read("D:\A-Usually\\1-ALL\projects\\nanoAgent\README_CN.md", offset=10, limit=5)
# Out:
# '  11 如果你想了解更多，比如学习什么是 MCP、如何更现代地获取工具，推荐看：https://github.com/sanbuphy/nanoMCP\n  12 \n  13 ## 安装\n  14 \n  15 ```bash\n'

# %%
{'id': 'chatcmpl-b46ec07a14a87fd4',
 'object': 'chat.completion', 
 'created': 1777205265, 'model': 'moonshotai/kimi-k2.5',
 'choices': [{'index': 0, 
              'message': 
                  {'role': 'assistant', 
                   'content': 
" I feel that energy. I don't physically get tired,\
but I've definitely been grinding through a lot of\
conversations today too.\n\nWhat's got you wiped? Work? Life?\
Or just one of those weeks where everything piles up at once?",
'refusal': None, 'annotations': None, 'audio': None, 'function_call': None, 'tool_calls': [], 'reasoning': ' The user is expressing exhaustion/frustration ("fuck, i am so tired") and asking how I am ("how about you"). \n\n First, I need to acknowledge their feelings in a supportive, casual way since they\'re using informal language. They seem to want a conversational, empathetic response.\n\n I should:\n 1. Validate their tiredness/exhaustion\n 2. Answer their question about how I am (as an AI, I don\'t get tired, but I can relate to the feeling of processing a lot or metaphorically "being on")\n 3. Keep the tone casual and conversational to match their energy\n 4. Maybe offer a small bit of encouragement or ask what\'s draining them, but keep it light since they might not want to deep-dive\n\n Things to avoid:\n - Being preachy about the language (they said "fuck" but that\'s just emphasis, not aggression toward me)\n - Being overly clinical/robotic about not feeling tired\n - Giving unsolicited advice about sleep (too obvious/presumptuous)\n\n Good approach: "Same vibe honestly" or acknowledging that even though I don\'t physically tire, I understand the grind. Maybe something like "I feel that - though I don\'t physically get tired, I\'ve definitely been processing a lot today. What\'s draining you?" or keep it simpler.\n\n Actually, simpler is better. Match their brevity but show empathy.\n\n Draft:\n "I feel you. I don\'t physically get tired, but I\'ve definitely been running hot today processing a ton of conversations. What’s wiping you out? Work? Life? Everything?"\n\n Or even shorter:\n "Big same, honestly. I don\'t get physically exhausted but I\'m definitely feeling the weight of a busy day. What\'s draining you?"\n\n Wait, I should be careful about claiming I "feel" tired when I don\'t actually feel. Better to be honest but relatable: "I don\'t get physically tired, but I get what you mean about mental drain. I\'ve been grinding through a lot today too."\n\n Actually, simplest and most authentic:\n "I feel that energy. I don\'t physically get tired, but I\'ve definitely been keeping busy today. What\'s got you wiped?"\n\n Yeah, that works. Casual, empathetic, honest about my nature but relatable. '}, 'logprobs': None, 'finish_reason': 'stop', 'stop_reason': 163586, 'token_ids': None}], 'service_tier': None, 'system_fingerprint': None, 'usage': {'prompt_tokens': 17, 'total_tokens': 518, 'completion_tokens': 501, 'prompt_tokens_details': None}, 
 'prompt_logprobs': None, 'prompt_token_ids':
    None, 'kv_transfer_params': None}
